# %%
import pandas as pd
from transformers import BertTokenizerFast, BertForTokenClassification
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import torch
import joblib
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
from transformers import BertForTokenClassification, BertTokenizerFast

model_path = "BIOBERT_model"
model = BertForTokenClassification.from_pretrained("BIOBERT_model")
tokenizer = BertTokenizerFast.from_pretrained("BIOBERT_tokenizer")

# %%
data = pd.read_csv('processed_entities_with_sentences_iob_18.csv')
data = data[data['Text_ID'] == 15939911]

# %%
import pandas as pd
from transformers import AutoTokenizer, PreTrainedTokenizerBase

def tokenize_and_preserve_labels(sentence: str, text_labels: list, tokenizer: PreTrainedTokenizerBase):
    tokenized_sentence = []
    labels = []

    for word, label in zip(sentence.split(), text_labels):
        tokenized_word = tokenizer.tokenize(word)
        n_subwords = len(tokenized_word)

        tokenized_sentence.extend(tokenized_word)
        
        if n_subwords > 0:
            if label.startswith('B-'):
                labels.append(label)
                labels.extend(['I-' + label.split('-')[1]] * (n_subwords - 1))
            else:
                labels.extend([label] * n_subwords)

    return tokenized_sentence, labels

sentence = " ".join(data['Token'].values)
text_labels = data['Label'].values.tolist()

tokenized_sentence, new_labels = tokenize_and_preserve_labels(sentence, text_labels, tokenizer)

tokenized_data_df = pd.DataFrame({'Token': tokenized_sentence, 'Label': new_labels})

# %%
tokenized_data_df
# Out:
#       Token  Label
# 0        CA      O
# 1      ##SE      O
# 2         :      O
# 3         A      O
# 4        28  B-Age
# ..      ...    ...
# 449     the      O
# 450       a      O
# 451   ##bla      O
# 452  ##tion      O
# 453       .      O
#
# [454 rows x 2 columns]

# %%
word_labels_list = []

current_word = ""
current_label = None

for index, row in tokenized_data_df.iterrows():
    token = row['Token']
    label = row['Label']

    if token.startswith("##"):
        current_word += token[2:]
    else:
        if current_word:
            word_labels_list.append({'Word': current_word, 'Label': current_label})
        current_word = token
        current_label = label

if current_word:
    word_labels_list.append({'Word': current_word, 'Label': current_label})

new_word_labels_df = pd.DataFrame(word_labels_list)

# %%
new_word_labels_df
# Out:
#          Word   Label
# 0        CASE       O
# 1           :       O
# 2           A       O
# 3          28   B-Age
# 4           -   I-Age
# ..        ...     ...
# 325    months  I-Date
# 326     after  I-Date
# 327       the       O
# 328  ablation       O
# 329         .       O
#
# [330 rows x 2 columns]

# %%
csv_file_path = 'test_label.csv'
new_word_labels_df.to_csv(csv_file_path, index=False)

# %%
file_path = "/home/jupyter/datasphere/project/maccrobat/18/15939911.txt"

with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# %%
text
# Out:
# "CASE: A 28-year-old previously healthy man presented with a 6-week history of palpitations.\nThe symptoms occurred during rest, 2–3 times per week, lasted up to 30 minutes at a time and were associated with dyspnea.\nExcept for a grade 2/6 holosystolic tricuspid regurgitation murmur (best heard at the left sternal border with inspiratory accentuation), physical examination yielded unremarkable findings.\nAn electrocardiogram (ECG) revealed normal sinus rhythm and a Wolff– Parkinson– White pre-excitation pattern (Fig.1: Top), produced by a right-sided accessory pathway.\nTransthoracic echocardiography demonstrated the presence of Ebstein's anomaly of the tricuspid valve, with apical displacement of the valve and formation of an “atrialized” right ventricle (a functional unit between the right atrium and the inlet [inflow] portion of the right ventricle) (Fig.2).\nThe anterior tricuspid valve leaflet was elongated (Fig.2C, arrow), whereas the septal leaflet was rudimentary (Fig.2C, arrowhead).\nContrast echocardiography using saline revealed a patent foramen ovale with right-to-left shunting and bubbles in the left atrium (Fig.2D).\nThe patient underwent an electrophysiologic study with mapping of the accessory pathway, followed by radiofrequency ablation (interruption of the pathway using the heat generated by electromagnetic waves at the tip of an ablation catheter).\nHis post-ablation ECG showed a prolonged PR interval and an odd “second” QRS complex in leads III, aVF and V2–V4 (Fig.1Bottom), a consequence of abnormal impulse conduction in the “atrialized” right ventricle.\nThe patient reported no recurrence of palpitations at follow-up 6 months after the ablation.\n"

# %%
label_encoder_path = "label_encoder.joblib"
label_encoder = joblib.load(label_encoder_path)

# %%
inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=256)

with torch.no_grad():
    outputs = model(**inputs)

logits = outputs.logits
predictions = torch.argmax(logits, dim=-1)

predicted_label_indices = predictions[0].numpy()
predicted_labels = [label_encoder.inverse_transform([idx])[0] for idx in predicted_label_indices]

# %%
tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0].cpu())
for token, label in zip(tokens, predicted_labels):
    print(f"{token}: {label}")
# Out:
# [CLS]: O
# CA: O
# ##SE: O
# :: O
# A: O
# 28: B-Age
# -: B-Age
# year: B-Age
# -: B-Age
# old: B-Age
# previously: B-History
# healthy: I-History
# man: B-Sex
# presented: B-Clinical_event
# with: O
# a: O
# 6: B-Duration
# -: B-Duration
# week: B-Duration
# history: O
# of: O
# p: B-Sign_symptom
# ##al: B-Sign_symptom
# ##pit: B-Sign_symptom
# ##ations: B-Sign_symptom
# .: O
# The: O
# symptoms: B-Sign_symptom
# occurred: O
# during: O
# rest: B-Activity
# ,: O
# 2: B-Frequency
# –: B-Frequency
# 3: B-Frequency
# times: I-Frequency
# per: I-Frequency
# week: I-Frequency
# ,: O
# lasted: O
# up: B-Detailed_description
# to: I-Detailed_description
# 30: I-Detailed_description
# minutes: I-Detailed_description
# at: I-Detailed_description
# a: I-Detailed_description
# time: I-Detailed_description
# and: O
# were: O
# associated: O
# with: O
# d: B-Sign_symptom
# ##ys: B-Sign_symptom
# ##p: B-Sign_symptom
# ##nea: B-Sign_symptom
# .: O
# Except: O
# for: O
# a: O
# grade: B-Lab_value
# 2: I-Lab_value
# /: I-Lab_value
# 6: I-Lab_value
# ho: B-Detailed_description
# ##los: B-Detailed_description
# ##ys: B-Detailed_description
# ##to: B-Detailed_description
# ##lic: B-Detailed_description
# t: B-Biological_structure
# ##ric: B-Biological_structure
# ##us: B-Biological_structure
# ##pid: B-Biological_structure
# re: B-Sign_symptom
# ##gu: B-Sign_symptom
# ##rg: B-Sign_symptom
# ##itation: B-Sign_symptom
# murmur: B-Sign_symptom
# (: O
# best: O
# heard: O
# at: O
# the: O
# left: B-Biological_structure
# stern: I-Biological_structure
# ##al: I-Biological_structure
# border: I-Biological_structure
# with: O
# ins: B-Detailed_description
# ##pi: B-Detailed_description
# ##rator: B-Detailed_description
# ##y: B-Detailed_description
# accent: I-Detailed_description
# ##uation: I-Detailed_description
# ): O
# ,: O
# physical: B-Diagnostic_procedure
# examination: I-Diagnostic_procedure
# yielded: O
# un: B-Lab_value
# ##rem: B-Lab_value
# ##ark: B-Lab_value
# ##able: B-Lab_value
# findings: O
# .: O
# An: O
# electro: B-Diagnostic_procedure
# ##card: B-Diagnostic_procedure
# ##io: B-Diagnostic_procedure
# ##gram: B-Diagnostic_procedure
# (: O
# EC: B-Diagnostic_procedure
# ##G: B-Diagnostic_procedure
# ): O
# revealed: O
# normal: B-Lab_value
# sin: B-Diagnostic_procedure
# ##us: B-Diagnostic_procedure
# rhythm: I-Diagnostic_procedure
# and: O
# a: O
# Wolff: B-Sign_symptom
# –: B-Sign_symptom
# Parkinson: B-Sign_symptom
# –: I-Sign_symptom
# White: I-Sign_symptom
# pre: I-Sign_symptom
# -: I-Sign_symptom
# ex: I-Sign_symptom
# ##citation: I-Sign_symptom
# pattern: I-Sign_symptom
# (: O
# Fi: O
# ##g: O
# .: O
# 1: O
# :: O
# Top: O
# ): O
# ,: O
# produced: O
# by: O
# a: O
# right: B-Detailed_description
# -: B-Detailed_description
# sided: B-Detailed_description
# access: B-Disease_disorder
# ##ory: B-Disease_disorder
# pathway: I-Disease_disorder
# .: O
# Trans: B-Biological_structure
# ##th: B-Biological_structure
# ##ora: B-Biological_structure
# ##ci: B-Biological_structure
# ##c: B-Biological_structure
# echo: B-Diagnostic_procedure
# ##card: B-Diagnostic_procedure
# ##io: B-Diagnostic_procedure
# ##graphy: B-Diagnostic_procedure
# demonstrated: O
# the: O
# presence: O
# of: O
# E: B-Disease_disorder
# ##bs: B-Disease_disorder
# ##tein: B-Disease_disorder
# ': I-Disease_disorder
# s: I-Disease_disorder
# an: I-Disease_disorder
# ##oma: I-Disease_disorder
# ##ly: I-Disease_disorder
# of: O
# the: O
# t: B-Biological_structure
# ##ric: B-Biological_structure
# ##us: B-Biological_structure
# ##pid: B-Biological_structure
# valve: I-Biological_structure
# ,: O
# with: O
# a: B-Sign_symptom
# ##pical: B-Sign_symptom
# displacement: I-Sign_symptom
# of: O
# the: O
# valve: B-Biological_structure
# and: O
# formation: O
# of: O
# an: O
# “: O
# at: B-Disease_disorder
# ##rial: B-Disease_disorder
# ##ized: B-Disease_disorder
# ”: O
# right: B-Biological_structure
# vent: I-Biological_structure
# ##ric: I-Biological_structure
# ##le: I-Biological_structure
# (: O
# a: O
# functional: O
# unit: O
# between: O
# the: O
# right: I-Biological_structure
# at: I-Biological_structure
# ##rium: I-Biological_structure
# and: O
# the: O
# inlet: B-Biological_structure
# [: O
# in: O
# ##flow: O
# ]: O
# portion: I-Biological_structure
# of: I-Biological_structure
# the: I-Biological_structure
# right: I-Biological_structure
# vent: I-Biological_structure
# ##ric: I-Biological_structure
# ##le: I-Biological_structure
# ): O
# (: O
# Fi: O
# ##g: O
# .: O
# 2: O
# ): O
# .: O
# The: O
# anterior: B-Biological_structure
# t: I-Biological_structure
# ##ric: I-Biological_structure
# ##us: I-Biological_structure
# ##pid: I-Biological_structure
# valve: I-Biological_structure
# leaf: I-Biological_structure
# ##let: I-Biological_structure
# was: O
# elongated: B-Sign_symptom
# (: O
# Fi: O
# ##g: O
# .: O
# 2: O
# ##C: O
# ,: O
# arrow: O
# ): O
# ,: O
# whereas: O
# the: O
# se: B-Biological_structure
# ##pta: B-Biological_structure
# ##l: B-Biological_structure
# [SEP]: O

# %%
word_labels = []
current_word = ""
current_label = None

for token, label in zip(tokens, predicted_labels):
    if token.startswith("##"):
        current_word += token[2:]
    else:
        if current_word:
            word_labels.append((current_word, current_label))
        current_word = token
        current_label = label if label.startswith("B-") else "O"

if current_word:
    word_labels.append((current_word, current_label))

# %%
word_labels
# Out:
# [('[CLS]', 'O'),
#  ('CASE', 'O'),
#  (':', 'O'),
#  ('A', 'O'),
#  ('28', 'B-Age'),
#  ('-', 'B-Age'),
#  ('year', 'B-Age'),
#  ('-', 'B-Age'),
#  ('old', 'B-Age'),
#  ('previously', 'B-History'),
#  ('healthy', 'O'),
#  ('man', 'B-Sex'),
#  ('presented', 'B-Clinical_event'),
#  ('with', 'O'),
#  ('a', 'O'),
#  ('6', 'B-Duration'),
#  ('-', 'B-Duration'),
#  ('week', 'B-Duration'),
#  ('history', 'O'),
#  ('of', 'O'),
#  ('palpitations', 'B-Sign_symptom'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('symptoms', 'B-Sign_symptom'),
#  ('occurred', 'O'),
#  ('during', 'O'),
#  ('rest', 'B-Activity'),
#  (',', 'O'),
#  ('2', 'B-Frequency'),
#  ('–', 'B-Frequency'),
#  ('3', 'B-Frequency'),
#  ('times', 'O'),
#  ('per', 'O'),
#  ('week', 'O'),
#  (',', 'O'),
#  ('lasted', 'O'),
#  ('up', 'B-Detailed_description'),
#  ('to', 'O'),
#  ('30', 'O'),
#  ('minutes', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('time', 'O'),
#  ('and', 'O'),
#  ('were', 'O'),
#  ('associated', 'O'),
#  ('with', 'O'),
#  ('dyspnea', 'B-Sign_symptom'),
#  ('.', 'O'),
#  ('Except', 'O'),
#  ('for', 'O'),
#  ('a', 'O'),
#  ('grade', 'B-Lab_value'),
#  ('2', 'O'),
#  ('/', 'O'),
#  ('6', 'O'),
#  ('holosystolic', 'B-Detailed_description'),
#  ('tricuspid', 'B-Biological_structure'),
#  ('regurgitation', 'B-Sign_symptom'),
#  ('murmur', 'B-Sign_symptom'),
#  ('(', 'O'),
#  ('best', 'O'),
#  ('heard', 'O'),
#  ('at', 'O'),
#  ('the', 'O'),
#  ('left', 'B-Biological_structure'),
#  ('sternal', 'O'),
#  ('border', 'O'),
#  ('with', 'O'),
#  ('inspiratory', 'B-Detailed_description'),
#  ('accentuation', 'O'),
#  (')', 'O'),
#  (',', 'O'),
#  ('physical', 'B-Diagnostic_procedure'),
#  ('examination', 'O'),
#  ('yielded', 'O'),
#  ('unremarkable', 'B-Lab_value'),
#  ('findings', 'O'),
#  ('.', 'O'),
#  ('An', 'O'),
#  ('electrocardiogram', 'B-Diagnostic_procedure'),
#  ('(', 'O'),
#  ('ECG', 'B-Diagnostic_procedure'),
#  (')', 'O'),
#  ('revealed', 'O'),
#  ('normal', 'B-Lab_value'),
#  ('sinus', 'B-Diagnostic_procedure'),
#  ('rhythm', 'O'),
#  ('and', 'O'),
#  ('a', 'O'),
#  ('Wolff', 'B-Sign_symptom'),
#  ('–', 'B-Sign_symptom'),
#  ('Parkinson', 'B-Sign_symptom'),
#  ('–', 'O'),
#  ('White', 'O'),
#  ('pre', 'O'),
#  ('-', 'O'),
#  ('excitation', 'O'),
#  ('pattern', 'O'),
#  ('(', 'O'),
#  ('Fig', 'O'),
#  ('.', 'O'),
#  ('1', 'O'),
#  (':', 'O'),
#  ('Top', 'O'),
#  (')', 'O'),
#  (',', 'O'),
#  ('produced', 'O'),
#  ('by', 'O'),
#  ('a', 'O'),
#  ('right', 'B-Detailed_description'),
#  ('-', 'B-Detailed_description'),
#  ('sided', 'B-Detailed_description'),
#  ('accessory', 'B-Disease_disorder'),
#  ('pathway', 'O'),
#  ('.', 'O'),
#  ('Transthoracic', 'B-Biological_structure'),
#  ('echocardiography', 'B-Diagnostic_procedure'),
#  ('demonstrated', 'O'),
#  ('the', 'O'),
#  ('presence', 'O'),
#  ('of', 'O'),
#  ('Ebstein', 'B-Disease_disorder'),
#  ("'", 'O'),
#  ('s', 'O'),
#  ('anomaly', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('tricuspid', 'B-Biological_structure'),
#  ('valve', 'O'),
#  (',', 'O'),
#  ('with', 'O'),
#  ('apical', 'B-Sign_symptom'),
#  ('displacement', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('valve', 'B-Biological_structure'),
#  ('and', 'O'),
#  ('formation', 'O'),
#  ('of', 'O'),
#  ('an', 'O'),
#  ('“', 'O'),
#  ('atrialized', 'B-Disease_disorder'),
#  ('”', 'O'),
#  ('right', 'B-Biological_structure'),
#  ('ventricle', 'O'),
#  ('(', 'O'),
#  ('a', 'O'),
#  ('functional', 'O'),
#  ('unit', 'O'),
#  ('between', 'O'),
#  ('the', 'O'),
#  ('right', 'O'),
#  ('atrium', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('inlet', 'B-Biological_structure'),
#  ('[', 'O'),
#  ('inflow', 'O'),
#  (']', 'O'),
#  ('portion', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('right', 'O'),
#  ('ventricle', 'O'),
#  (')', 'O'),
#  ('(', 'O'),
#  ('Fig', 'O'),
#  ('.', 'O'),
#  ('2', 'O'),
#  (')', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('anterior', 'B-Biological_structure'),
#  ('tricuspid', 'O'),
#  ('valve', 'O'),
#  ('leaflet', 'O'),
#  ('was', 'O'),
#  ('elongated', 'B-Sign_symptom'),
#  ('(', 'O'),
#  ('Fig', 'O'),
#  ('.', 'O'),
#  ('2C', 'O'),
#  (',', 'O'),
#  ('arrow', 'O'),
#  (')', 'O'),
#  (',', 'O'),
#  ('whereas', 'O'),
#  ('the', 'O'),
#  ('septal', 'B-Biological_structure'),
#  ('[SEP]', 'O')]

# %%
word_labels_df = pd.DataFrame(word_labels, columns=['Word', 'Label'])
word_labels_df
# Out:
#         Word                   Label
# 0      [CLS]                       O
# 1       CASE                       O
# 2          :                       O
# 3          A                       O
# 4         28                   B-Age
# ..       ...                     ...
# 186        ,                       O
# 187  whereas                       O
# 188      the                       O
# 189   septal  B-Biological_structure
# 190    [SEP]                       O
#
# [191 rows x 2 columns]

# %%
filtered_df = word_labels_df[~word_labels_df['Word'].isin(['[PAD]'])]
filtered_df = filtered_df[~filtered_df['Word'].isin(['[CLS]'])]
filtered_df = filtered_df[~filtered_df['Word'].isin(['[SEP]'])]
filtered_df
# Out:
#         Word                   Label
# 1       CASE                       O
# 2          :                       O
# 3          A                       O
# 4         28                   B-Age
# 5          -                   B-Age
# ..       ...                     ...
# 185        )                       O
# 186        ,                       O
# 187  whereas                       O
# 188      the                       O
# 189   septal  B-Biological_structure
#
# [189 rows x 2 columns]

# %%
csv_file_path = 'test_pred.csv'
filtered_df.to_csv(csv_file_path, index=False)

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report

test_labels_df = new_word_labels_df
test_preds_df = filtered_df

test_labels_df['Label'] = test_labels_df['Label'].str.replace(r'^(B-|I-)', '', regex=True)
test_preds_df['Label'] = test_preds_df['Label'].str.replace(r'^(B-|I-)', '', regex=True)
test_labels_df = test_labels_df[:min(len(test_labels_df), len(test_preds_df))]
test_preds_df = test_preds_df[:min(len(test_labels_df), len(test_preds_df))]

assert len(test_labels_df) == len(test_preds_df), "DataFrames have different lengths"

y_true = test_labels_df['Label'].values
y_pred = test_preds_df['Label'].values

# %%
y_true
# Out:
# array(['O', 'O', 'O', 'Age', 'Age', 'Age', 'Age', 'Age', 'History',
#        'History', 'Sex', 'Clinical_event', 'O', 'O', 'Duration',
#        'Duration', 'Duration', 'O', 'O', 'Sign_symptom', 'O', 'O',
#        'Coreference', 'O', 'O', 'Clinical_event', 'O', 'Frequency',
#        'Frequency', 'Frequency', 'Frequency', 'Frequency', 'Frequency',
#        'O', 'O', 'Detailed_description', 'Detailed_description',
#        'Detailed_description', 'Detailed_description',
#        'Detailed_description', 'Detailed_description',
#        'Detailed_description', 'O', 'O', 'O', 'O', 'Sign_symptom', 'O',
#        'O', 'O', 'O', 'Lab_value', 'Lab_value', 'Lab_value', 'Lab_value',
#        'Detailed_description', 'Biological_structure', 'Sign_symptom',
#        'Sign_symptom', 'O', 'O', 'O', 'O', 'O', 'Biological_structure',
#        'Biological_structure', 'Biological_structure', 'O',
#        'Detailed_description', 'Detailed_description', 'O', 'O',
#        'Diagnostic_procedure', 'Diagnostic_procedure', 'O', 'Lab_value',
#        'O', 'O', 'O', 'Diagnostic_procedure', 'O', 'Diagnostic_procedure',
#        'O', 'O', 'Lab_value', 'Diagnostic_procedure',
#        'Diagnostic_procedure', 'O', 'O', 'Sign_symptom', 'Sign_symptom',
#        'Sign_symptom', 'Sign_symptom', 'Sign_symptom', 'Sign_symptom',
#        'Sign_symptom', 'Sign_symptom', 'Sign_symptom', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Detailed_description',
#        'Detailed_description', 'Detailed_description', 'Disease_disorder',
#        'Disease_disorder', 'O', 'Biological_structure',
#        'Diagnostic_procedure', 'O', 'O', 'O', 'O', 'Disease_disorder',
#        'Disease_disorder', 'Disease_disorder', 'Disease_disorder', 'O',
#        'O', 'Biological_structure', 'Biological_structure', 'O', 'O',
#        'Sign_symptom', 'Sign_symptom', 'O', 'O', 'Coreference', 'O', 'O',
#        'O', 'O', 'O', 'Disease_disorder', 'O', 'Biological_structure',
#        'Biological_structure', 'O', 'O', 'O', 'O', 'O', 'O',
#        'Biological_structure', 'Biological_structure', 'O', 'O',
#        'Biological_structure', 'O', 'O', 'O', 'O', 'O', 'O',
#        'Biological_structure', 'Biological_structure', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'Biological_structure', 'Biological_structure',
#        'Biological_structure', 'Biological_structure', 'O',
#        'Sign_symptom', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'Biological_structure'], dtype=object)

# %%
y_pred
# Out:
# array(['O', 'O', 'O', 'Age', 'Age', 'Age', 'Age', 'Age', 'History', 'O',
#        'Sex', 'Clinical_event', 'O', 'O', 'Duration', 'Duration',
#        'Duration', 'O', 'O', 'Sign_symptom', 'O', 'O', 'Sign_symptom',
#        'O', 'O', 'Activity', 'O', 'Frequency', 'Frequency', 'Frequency',
#        'O', 'O', 'O', 'O', 'O', 'Detailed_description', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Sign_symptom', 'O', 'O', 'O',
#        'O', 'Lab_value', 'O', 'O', 'O', 'Detailed_description',
#        'Biological_structure', 'Sign_symptom', 'Sign_symptom', 'O', 'O',
#        'O', 'O', 'O', 'Biological_structure', 'O', 'O', 'O',
#        'Detailed_description', 'O', 'O', 'O', 'Diagnostic_procedure', 'O',
#        'O', 'Lab_value', 'O', 'O', 'O', 'Diagnostic_procedure', 'O',
#        'Diagnostic_procedure', 'O', 'O', 'Lab_value',
#        'Diagnostic_procedure', 'O', 'O', 'O', 'Sign_symptom',
#        'Sign_symptom', 'Sign_symptom', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'Detailed_description', 'Detailed_description',
#        'Detailed_description', 'Disease_disorder', 'O', 'O',
#        'Biological_structure', 'Diagnostic_procedure', 'O', 'O', 'O', 'O',
#        'Disease_disorder', 'O', 'O', 'O', 'O', 'O',
#        'Biological_structure', 'O', 'O', 'O', 'Sign_symptom', 'O', 'O',
#        'O', 'Biological_structure', 'O', 'O', 'O', 'O', 'O',
#        'Disease_disorder', 'O', 'Biological_structure', 'O', 'O', 'O',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Biological_structure',
#        'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'O', 'O', 'O', 'Biological_structure', 'O', 'O', 'O', 'O',
#        'Sign_symptom', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O',
#        'Biological_structure'], dtype=object)

# %%
print("\nClassification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#                       precision    recall  f1-score   support
#
#             Activity       0.00      0.00      0.00         0
#                  Age       1.00      1.00      1.00         5
# Biological_structure       0.89      0.42      0.57        19
#       Clinical_event       1.00      0.50      0.67         2
#          Coreference       0.00      0.00      0.00         2
# Detailed_description       1.00      0.46      0.63        13
# Diagnostic_procedure       1.00      0.71      0.83         7
#     Disease_disorder       1.00      0.43      0.60         7
#             Duration       1.00      1.00      1.00         3
#            Frequency       1.00      0.50      0.67         6
#              History       1.00      0.50      0.67         2
#            Lab_value       1.00      0.50      0.67         6
#                    O       0.72      1.00      0.84       100
#                  Sex       1.00      1.00      1.00         1
#         Sign_symptom       0.90      0.56      0.69        16
#
#             accuracy                           0.78       189
#            macro avg       0.83      0.57      0.66       189
#         weighted avg       0.82      0.78      0.76       189
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
